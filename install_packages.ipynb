# %%
# !pip install pandas 
# !pip install warnings
# !pip install networkx 
# !pip install cdlib 
# !pip install os
# !pip install networkx 
# !pip install matplotlib
# !pip install seaborn 
# !pip install IPython
# !pip install pyspark_dist_explore
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/site-packages (2.1.4)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.10/site-packages (from pandas) (1.25.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# ERROR: Could not find a version that satisfies the requirement warnings (from versions: none)
# ERROR: No matching distribution found for warnings
# Collecting networkx
#   Downloading networkx-3.3-py3-none-any.whl.metadata (5.1 kB)
# Downloading networkx-3.3-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 39.5 MB/s eta 0:00:0000:01
# Installing collected packages: networkx
# Successfully installed networkx-3.3
# Collecting cdlib
#   Downloading cdlib-0.3.0-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/site-packages (from cdlib) (1.25.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/site-packages (from cdlib) (3.7.0)
# Collecting scikit-learn (from cdlib)
#   Downloading scikit_learn-1.4.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting tqdm (from cdlib)
#   Downloading tqdm-4.66.2-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: networkx>=3.0 in ./.local/lib/python3.10/site-packages (from cdlib) (3.3)
# Collecting demon (from cdlib)
#   Downloading demon-2.0.6-py3-none-any.whl.metadata (5.1 kB)
# Collecting python-louvain>=0.16 (from cdlib)
#   Downloading python-louvain-0.16.tar.gz (204 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.6/204.6 kB 15.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting nf1 (from cdlib)
#   Downloading nf1-0.0.4-py3-none-any.whl.metadata (805 bytes)
# Collecting scipy (from cdlib)
#   Downloading scipy-1.13.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 6.4 MB/s eta 0:00:00
# Collecting pulp (from cdlib)
#   Downloading PuLP-2.8.0-py3-none-any.whl.metadata (5.4 kB)
# Collecting seaborn (from cdlib)
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/site-packages (from cdlib) (2.1.4)
# Collecting eva-lcd (from cdlib)
#   Downloading eva_lcd-0.1.1-py3-none-any.whl.metadata (731 bytes)
# Collecting bimlpa (from cdlib)
#   Downloading bimlpa-0.1.2-py3-none-any.whl.metadata (725 bytes)
# Collecting markov-clustering (from cdlib)
#   Downloading markov_clustering-0.0.6.dev0-py3-none-any.whl.metadata (947 bytes)
# Collecting python-igraph>=0.10 (from cdlib)
#   Downloading python_igraph-0.11.4-py3-none-any.whl.metadata (2.8 kB)
# Collecting angelcommunity (from cdlib)
#   Downloading angelcommunity-2.0.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting pooch (from cdlib)
#   Downloading pooch-1.8.1-py3-none-any.whl.metadata (9.5 kB)
# Collecting dynetx (from cdlib)
#   Downloading dynetx-0.3.2-py3-none-any.whl.metadata (2.9 kB)
# Collecting thresholdclustering (from cdlib)
#   Downloading thresholdclustering-1.1-py3-none-any.whl.metadata (4.2 kB)
# Collecting python-Levenshtein (from cdlib)
#   Downloading python_Levenshtein-0.25.1-py3-none-any.whl.metadata (3.7 kB)
# Collecting igraph==0.11.4 (from python-igraph>=0.10->cdlib)
#   Downloading igraph-0.11.4-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.9 kB)
# Collecting texttable>=1.6.2 (from igraph==0.11.4->python-igraph>=0.10->cdlib)
#   Downloading texttable-1.7.0-py2.py3-none-any.whl.metadata (9.8 kB)
# Collecting future (from angelcommunity->cdlib)
#   Downloading future-1.0.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/site-packages (from dynetx->cdlib) (4.4.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/site-packages (from matplotlib->cdlib) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/site-packages (from matplotlib->cdlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/site-packages (from matplotlib->cdlib) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/site-packages (from matplotlib->cdlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/site-packages (from matplotlib->cdlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/site-packages (from matplotlib->cdlib) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/site-packages (from matplotlib->cdlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/site-packages (from matplotlib->cdlib) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/site-packages (from pandas->cdlib) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/site-packages (from pandas->cdlib) (2023.3)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/site-packages (from pooch->cdlib) (3.5.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/site-packages (from pooch->cdlib) (2.31.0)
# Collecting Levenshtein==0.25.1 (from python-Levenshtein->cdlib)
#   Downloading Levenshtein-0.25.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.3 kB)
# Collecting rapidfuzz<4.0.0,>=3.8.0 (from Levenshtein==0.25.1->python-Levenshtein->cdlib)
#   Downloading rapidfuzz-3.8.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting joblib>=1.2.0 (from scikit-learn->cdlib)
#   Downloading joblib-1.4.0-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn->cdlib)
#   Downloading threadpoolctl-3.4.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->cdlib) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/site-packages (from requests>=2.19.0->pooch->cdlib) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/site-packages (from requests>=2.19.0->pooch->cdlib) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/site-packages (from requests>=2.19.0->pooch->cdlib) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/site-packages (from requests>=2.19.0->pooch->cdlib) (2023.7.22)
# Downloading cdlib-0.3.0-py3-none-any.whl (230 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 230.3/230.3 kB 23.4 MB/s eta 0:00:00
# Downloading python_igraph-0.11.4-py3-none-any.whl (9.1 kB)
# Downloading igraph-0.11.4-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 100.9 MB/s eta 0:00:00
# Downloading angelcommunity-2.0.0-py3-none-any.whl (10 kB)
# Downloading bimlpa-0.1.2-py3-none-any.whl (7.0 kB)
# Downloading demon-2.0.6-py3-none-any.whl (7.3 kB)
# Downloading dynetx-0.3.2-py3-none-any.whl (39 kB)
# Downloading eva_lcd-0.1.1-py3-none-any.whl (9.2 kB)
# Downloading markov_clustering-0.0.6.dev0-py3-none-any.whl (6.3 kB)
# Downloading scipy-1.13.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.6/38.6 MB 5.3 MB/s eta 0:00:000:00:0100:01
# Downloading nf1-0.0.4-py3-none-any.whl (18 kB)
# Downloading pooch-1.8.1-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 kB 6.1 MB/s eta 0:00:00
# Downloading PuLP-2.8.0-py3-none-any.whl (17.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.7/17.7 MB 10.2 MB/s eta 0:00:00:00:010:01
# Downloading python_Levenshtein-0.25.1-py3-none-any.whl (9.4 kB)
# Downloading Levenshtein-0.25.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (177 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.4/177.4 kB 18.0 MB/s eta 0:00:00
# Downloading scikit_learn-1.4.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 14.7 MB/s eta 0:00:00:00:010:01
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 31.0 MB/s eta 0:00:00
# Downloading thresholdclustering-1.1-py3-none-any.whl (5.3 kB)
# Downloading tqdm-4.66.2-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 8.9 MB/s eta 0:00:00
# Downloading joblib-1.4.0-py3-none-any.whl (301 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.2/301.2 kB 34.4 MB/s eta 0:00:00
# Downloading threadpoolctl-3.4.0-py3-none-any.whl (17 kB)
# Downloading future-1.0.0-py3-none-any.whl (491 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.3/491.3 kB 46.0 MB/s eta 0:00:00
# Downloading rapidfuzz-3.8.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 23.4 MB/s eta 0:00:00:00:01
# Downloading texttable-1.7.0-py2.py3-none-any.whl (10 kB)
# Building wheels for collected packages: python-louvain
#   Building wheel for python-louvain (setup.py) ... done
#   Created wheel for python-louvain: filename=python_louvain-0.16-py3-none-any.whl size=9389 sha256=00c128c3e8408a5b18baba208118501387c25166c2594260f0004baf658f81ed
#   Stored in directory: /home/cdsw/.cache/pip/wheels/d0/b0/d7/6dd26c3817810fa379088eaeb755a01d9a2a411c37632079d1
# Successfully built python-louvain
# Installing collected packages: texttable, tqdm, thresholdclustering, threadpoolctl, scipy, rapidfuzz, python-louvain, pulp, joblib, igraph, future, eva-lcd, scikit-learn, python-igraph, pooch, Levenshtein, dynetx, demon, seaborn, python-Levenshtein, nf1, markov-clustering, bimlpa, angelcommunity, cdlib
# Successfully installed Levenshtein-0.25.1 angelcommunity-2.0.0 bimlpa-0.1.2 cdlib-0.3.0 demon-2.0.6 dynetx-0.3.2 eva-lcd-0.1.1 future-1.0.0 igraph-0.11.4 joblib-1.4.0 markov-clustering-0.0.6.dev0 nf1-0.0.4 pooch-1.8.1 pulp-2.8.0 python-Levenshtein-0.25.1 python-igraph-0.11.4 python-louvain-0.16 rapidfuzz-3.8.1 scikit-learn-1.4.2 scipy-1.13.0 seaborn-0.13.2 texttable-1.7.0 threadpoolctl-3.4.0 thresholdclustering-1.1 tqdm-4.66.2
# ERROR: Could not find a version that satisfies the requirement os (from versions: none)
# ERROR: No matching distribution found for os
# Requirement already satisfied: networkx in ./.local/lib/python3.10/site-packages (3.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/site-packages (3.7.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/site-packages (from matplotlib) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/site-packages (from matplotlib) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/site-packages (from matplotlib) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: seaborn in ./.local/lib/python3.10/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /usr/local/lib/python3.10/site-packages (from seaborn) (1.25.2)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.10/site-packages (from seaborn) (2.1.4)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /usr/local/lib/python3.10/site-packages (from seaborn) (3.7.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Requirement already satisfied: IPython in /usr/local/lib/python3.10/site-packages (8.10.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/site-packages (from IPython) (0.2.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/site-packages (from IPython) (4.4.2)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/site-packages (from IPython) (0.18.2)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/site-packages (from IPython) (0.1.3)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/site-packages (from IPython) (0.7.5)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.30 in /usr/local/lib/python3.10/site-packages (from IPython) (3.0.38)
# Requirement already satisfied: pygments>=2.4.0 in /usr/local/lib/python3.10/site-packages (from IPython) (2.15.1)
# Requirement already satisfied: stack-data in /usr/local/lib/python3.10/site-packages (from IPython) (0.6.2)
# Requirement already satisfied: traitlets>=5 in /usr/local/lib/python3.10/site-packages (from IPython) (5.9.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/site-packages (from IPython) (4.8.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.10/site-packages (from jedi>=0.16->IPython) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/site-packages (from pexpect>4.3->IPython) (0.6.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.30->IPython) (0.2.5)
# Requirement already satisfied: executing>=1.2.0 in /usr/local/lib/python3.10/site-packages (from stack-data->IPython) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /usr/local/lib/python3.10/site-packages (from stack-data->IPython) (2.2.1)
# Requirement already satisfied: pure-eval in /usr/local/lib/python3.10/site-packages (from stack-data->IPython) (0.2.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/site-packages (from asttokens>=2.1.0->stack-data->IPython) (1.16.0)
# Collecting pyspark_dist_explore
#   Downloading pyspark_dist_explore-0.1.8-py3-none-any.whl.metadata (353 bytes)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/site-packages (from pyspark_dist_explore) (2.1.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/site-packages (from pyspark_dist_explore) (1.25.2)
# Requirement already satisfied: scipy in ./.local/lib/python3.10/site-packages (from pyspark_dist_explore) (1.13.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/site-packages (from pyspark_dist_explore) (3.7.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/site-packages (from matplotlib->pyspark_dist_explore) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/site-packages (from matplotlib->pyspark_dist_explore) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/site-packages (from matplotlib->pyspark_dist_explore) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/site-packages (from matplotlib->pyspark_dist_explore) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/site-packages (from matplotlib->pyspark_dist_explore) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/site-packages (from matplotlib->pyspark_dist_explore) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/site-packages (from matplotlib->pyspark_dist_explore) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/site-packages (from matplotlib->pyspark_dist_explore) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/site-packages (from pandas->pyspark_dist_explore) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/site-packages (from pandas->pyspark_dist_explore) (2023.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->pyspark_dist_explore) (1.16.0)
# Downloading pyspark_dist_explore-0.1.8-py3-none-any.whl (7.2 kB)
# Installing collected packages: pyspark_dist_explore
# Successfully installed pyspark_dist_explore-0.1.8
